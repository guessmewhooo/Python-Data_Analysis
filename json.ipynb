# %%
import pandas as pd
import json

# %%
with open("./cell_phones_survey.json", "r", encoding="utf-8-sig") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# %%
with open("./github.json", "r", encoding="utf-8-sig") as github:
     github_df = json.load(github)

df = pd.DataFrame(github_df)
df
# Out:
#      owner           name  stars  forks  watchers  isFork  \
# 0  pelmers  text-rewriter     11      4         3   False
# 1  pelmers  text-rewriter     11      4         3   False
# 2  pelmers  text-rewriter     11      4         3   False
#
#                                languages  \
# 0  {'name': 'JavaScript', 'size': 21769}
# 1         {'name': 'HTML', 'size': 2096}
# 2          {'name': 'CSS', 'size': 2081}
#
#                                 description             createdAt  \
# 0  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
# 1  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
# 2  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
#
#                pushedAt license
# 0  2022-02-11T14:26:00Z    None
# 1  2022-02-11T14:26:00Z    None
# 2  2022-02-11T14:26:00Z    None

# %%
df1 = pd.read_csv("./fifa_players.csv", low_memory=False)

# %%
index_col = "sofifa_id"
pd.read_csv("./fifa_players.csv",low_memory=False)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     201197  https://sofifa.com/player/201197/paul-tisdale/...
# 16153     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16154     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
pd.set_option("display.max_columns", 150)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.set_option("display.max_columns", 150)
#       2 df1
#
# NameError: name 'pd' is not defined

# %%
pd.set_option("display.max_colwidth", 500)
df1
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1.head()
# Out:
#    sofifa_id  \
# 0     158023
# 1      20801
# 2       9014
# 3      41236
# 4     167495
#
#                                                            player_url  \
# 0                https://sofifa.com/player/158023/lionel-messi/150002
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                  https://sofifa.com/player/9014/arjen-robben/150002
# 3           https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                https://sofifa.com/player/167495/manuel-neuer/150002
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini               CF
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, LM
# 2          A. Robben                         Arjen Robben       RM, LM, RW
# 3     Z. Ibrahimović                   Zlatan Ibrahimović               ST
# 4           M. Neuer                   Manuel Peter Neuer               GK
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), str(50)
# memory usage: 13.6 MB

# %%
df1.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   16155.000000  16155.000000  16155.000000  1.584400e+04   15916.000000
# mean   189298.540699     63.830393     68.350108  1.081706e+06   13252.513194
# std     39762.547872      7.169896      6.580610  2.842704e+06   23608.922510
# min         2.000000     40.000000     40.000000  1.000000e+03    2000.000000
# 25%    178042.500000     59.000000     64.000000  1.300000e+05    2000.000000
# 50%    200844.000000     64.000000     68.000000  3.500000e+05    5000.000000
# 75%    214349.500000     68.000000     73.000000  8.250000e+05   10000.000000
# max    254664.000000     93.000000     95.000000  1.005000e+08  550000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  16155.000000  16155.000000  16155.000000   15916.000000  15916.000000
# mean      24.776230    181.083627     75.474342   39905.174353      1.378424
# ...

# %%
df1.sample(10)
# Out:
#        sofifa_id  \
# 10253     169700
# 4711      242330
# 3919      218667
# 2327      213516
# 9593      192279
# 13107     225012
# 3222      203671
# 13065     224198
# 11201     194679
# 10245     166764
#
#                                                                    player_url  \
# 10253                    https://sofifa.com/player/169700/myles-weston/150002
# 4711                      https://sofifa.com/player/242330/ariel-nunez/150002
# 3919   https://sofifa.com/player/218667/bernardo-mota-carvalho-e-silva/150002
# 2327       https://sofifa.com/player/213516/ricardo-jorge-da-luz-horta/150002
# 9593                      https://sofifa.com/player/192279/igor-shitov/150002
# 13107                 https://sofifa.com/player/225012/segun-owobowale/150002
# 3222               https://sofifa.com/player/203671/juan-ignacio-gomez/150002
# 13065                     https://sofifa.com/player/224198/karim-hafez/150002
# ...

# %%
df1["sofifa_id"].isnull().sum
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16150    False
# 16151    False
# 16152    False
# 16153    False
# 16154    False
# Name: sofifa_id, Length: 16155, dtype: bool>

# %%
df1[df1["overall"].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
df1.duplicated(subset=["short_name","long_name"]).value_counts()
# Out:
# False    16129
# True        26
# Name: count, dtype: int64

# %%
df1["age"].sort_values()
# Out:
# 14371    16
# 16118    16
# 16107    16
# 15435    16
# 15779    16
#          ..
# 405      43
# 16143    44
# 10365    44
# 15839    44
# 3403     44
# Name: age, Length: 16155, dtype: int64

# %%
df1.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   16155.000000  16155.000000  16155.000000  1.584400e+04   15916.000000
# mean   189298.540699     63.830393     68.350108  1.081706e+06   13252.513194
# std     39762.547872      7.169896      6.580610  2.842704e+06   23608.922510
# min         2.000000     40.000000     40.000000  1.000000e+03    2000.000000
# 25%    178042.500000     59.000000     64.000000  1.300000e+05    2000.000000
# 50%    200844.000000     64.000000     68.000000  3.500000e+05    5000.000000
# 75%    214349.500000     68.000000     73.000000  8.250000e+05   10000.000000
# max    254664.000000     93.000000     95.000000  1.005000e+08  550000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  16155.000000  16155.000000  16155.000000   15916.000000  15916.000000
# mean      24.776230    181.083627     75.474342   39905.174353      1.378424
# ...

# %%
df1
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1 = df1.rename(index = {"2_" :"2"})

# %%
df1 = df1.rename(columns = str.lower)
df1
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1.set_index("short_name")
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# A. Robben               9014
# Z. Ibrahimović         41236
# M. Neuer              167495
# ...                      ...
# E. Redman             220806
# A. Collins            225509
# P. Tisdale            201197
# P. Żemło              217591
# T. Davies             222947
#
#                                                                            player_url  \
# short_name
# L. Messi                         https://sofifa.com/player/158023/lionel-messi/150002
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# A. Robben                          https://sofifa.com/player/9014/arjen-robben/150002
# Z. Ibrahimović              https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# M. Neuer                         https://sofifa.com/player/167495/manuel-neuer/150002
# ...

# %%
df1.reset_index()
# Out:
#        index  sofifa_id  \
# 0          0     158023
# 1          1      20801
# 2          2       9014
# 3          3      41236
# 4          4     167495
# ...      ...        ...
# 16150  16150     220806
# 16151  16151     225509
# 16152  16152     201197
# 16153  16153     217591
# 16154  16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# ...

# %%
df1.sort_index()
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1.sort_index(inplace = True)
df1
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1[["人口","面积","2","3","4","5","6"]] = df1["player_url"].str.split("/", expand = True)
df1
# Out:
#        sofifa_id  \
# 0         158023
# 1          20801
# 2           9014
# 3          41236
# 4         167495
# ...          ...
# 16150     220806
# 16151     225509
# 16152     201197
# 16153     217591
# 16154     222947
#
#                                                                player_url  \
# 0                    https://sofifa.com/player/158023/lionel-messi/150002
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2                      https://sofifa.com/player/9014/arjen-robben/150002
# 3               https://sofifa.com/player/41236/zlatan-ibrahimovic/150002
# 4                    https://sofifa.com/player/167495/manuel-neuer/150002
# ...                                                                   ...
# 16150                https://sofifa.com/player/220806/ellis-redman/150002
# 16151               https://sofifa.com/player/225509/aaron-collins/150002
# 16152                https://sofifa.com/player/201197/paul-tisdale/150002
# ...

# %%
df1 = df1.drop("player_url", axis = 1)

# %%
df1
# Out:
#        sofifa_id         short_name                            long_name  \
# 0         158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1          20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2           9014          A. Robben                         Arjen Robben
# 3          41236     Z. Ibrahimović                   Zlatan Ibrahimović
# 4         167495           M. Neuer                   Manuel Peter Neuer
# ...          ...                ...                                  ...
# 16150     220806          E. Redman                         Ellis Redman
# 16151     225509         A. Collins            Aaron Graham John Collins
# 16152     201197         P. Tisdale                         Paul Tisdale
# 16153     217591           P. Żemło                          Piotr Żemło
# 16154     222947          T. Davies            Thomas Christopher Davies
#
#       player_positions  overall  potential    value_eur  wage_eur  age  \
# ...

# %%
df1[""].str.cat(df3["名"],sep="-")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
pd.melt(df4,id_vars = ["国家代码", "年份"]), var_name = '年龄组', value_name = '肺结核病例数')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pd.melt(df4,id_vars = ["国家代码", "年份"])
#
# NameError: name 'df4' is not defined

# %%
df1["B"].fillna(0)#调用时所有NaN值都会被替换成传入的参数(0),还可以传入df4["B"].fillna(df["B"].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1["B"].fillna(0)#调用时所有NaN值都会被替换成传入的参数(0),还可以传入df4["B"].fillna(df["B"].mean())
#
# NameError: name 'df1' is not defined

# %%
df5.dropna()#只要某一行时空缺的, 调用dropna就看不到它了
df5.dropna(subset = ["工资"],axis = 0,inplace = True)#删除存在缺失值的行,axis=0删除横行, axis=1时删除竖列
df5.drop_duplicates()#删除所有重复项
df5.drop_duplicates(subset= ["姓名","性别"])#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df5.dropna()#只要某一行时空缺的, 调用dropna就看不到它了
#       2 df5.dropna(subset = ["工资"],axis = 0,inplace = True)#删除存在缺失值的行,axis=0删除横行, axis=1时删除竖列
#       3 df5.drop_duplicates()#删除所有重复项
#       4 df5.drop_duplicates(subset= ["姓名","性别"])#
#
# NameError: name 'df5' is not defined

# %%
df6 = pd.DataFrame({
    '姓名': ['John', 'Alice', 'Bob', 'Alice', 'John'],
    '年龄': [25, 30, 35, 30, 40],
    '性别': ['M', 'F', 'M', 'F', 'M']
})
df6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df6 = pd.DataFrame({
#       2     '姓名': ['John', 'Alice', 'Bob', 'Alice', 'John'],
#       3     '年龄': [25, 30, 35, 30, 40],
#       4     '性别': ['M', 'F', 'M', 'F', 'M']
#
# NameError: name 'pd' is not defined
